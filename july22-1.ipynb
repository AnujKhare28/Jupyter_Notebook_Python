# %%
import seaborn as sns
import statistics
from scipy import stats
import numpy as np

# %%
data = [20,21,22,25,26,29,33,34,38]
stats.skew(data)
# Out:
# np.float64(0.3456494605102496)

# %%
stats.kurtosis(data)
# Out:
# np.float64(-1.2130829964328183)

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
data = [20,21,22,25,26,29,33,34,38,1000]
stats.skew(data)
# Out:
# np.float64(2.6647772684028395)

# %%
stats.kurtosis(data)
# Out:
# np.float64(5.105221743737234)

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
data = [20,21,22,25,26,29,33,34,38,-1000]
stats.skew(data)
# Out:
# np.float64(-2.664969739224319)

# %%
stats.kurtosis(data)
# Out:
# np.float64(5.105842433687849)

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
data = [20,21,22,25,26,29,33,34,38,27,28,27,28,27,27,28,1000]
stats.kurtosis(data)
# Out:
# np.float64(12.051673963623678)

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>
