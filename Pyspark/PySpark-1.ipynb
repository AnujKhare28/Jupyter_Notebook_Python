# %%
dir(spark)
# Out:
# ['Builder',
#  'Hook',
#  '__annotations__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_active_session',
#  '_cache_local_relation',
#  '_client',
#  '_create_remote_dataframe',
#  '_default_session',
#  '_effective_usage_policy_id',
#  '_getActiveSessionIfMatches',
#  '_get_default_session',
#  '_inferSchemaFromList',
#  '_init_client',
#  '_init_session_id',
#  '_lock',
#  '_parse_ddl',
#  '_profiler_collector',
#  '_pythonEnv',
#  '_register_streaming_callback',
#  '_session_id',
#  '_set_default_and_active_session',
#  '_start_connect_server',
#  '_streaming_start_call_back',
#  '_to_ddl',
#  'active',
#  'addArtifact',
#  'addArtifacts',
#  'addGlobalUserContextExtension',
#  'addTag',
#  'addThreadlocalUserContextExtension',
#  'builder',
#  'catalog',
#  'clearProgressHandlers',
#  'clearTags',
#  'clearUserContextExtensions',
#  'client',
#  'conf',
#  'copyFromLocalToFs',
#  'createDataFrame',
#  'dataSource',
#  'getActiveSession',
#  'getTags',
#  'interruptAll',
#  'interruptOperation',
#  'interruptTag',
#  'is_stopped',
#  'profile',
#  'range',
#  'read',
#  'readStream',
#  'registerProgressHandler',
#  'release_session_on_close',
#  'removeProgressHandler',
#  'removeTag',
#  'removeUserContextExtension',
#  'session_id',
#  'sql',
#  'stop',
#  'streams',
#  'table',
#  'thread_local',
#  'tvf',
#  'udf',
#  'udtf',
#  'version']

# %%
from pyspark.sql.types import *

data = [(1,'Anuj'),(2,'Ravi'),(3,'Raj')]

schema = StructType([StructField(name="id",dataType = IntegerType()),StructField(name="name",dataType = StringType())])

df = spark.createDataFrame(data = data, schema= schema)
df.show()
# Out:
# +---+----+
# | id|name|
# +---+----+
# |  1|Anuj|
# |  2|Ravi|
# |  3| Raj|
# +---+----+

# %%
df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
from pyspark.sql.types import *

data = [{"id":1,"name":"Anuj"}, {"id":2,"name":"Ravi"}, {"id":3,"name":"Raj"}]

df = spark.createDataFrame(data = data)
df.show()
# Out:
# +---+----+
# | id|name|
# +---+----+
# |  1|Anuj|
# |  2|Ravi|
# |  3| Raj|
# +---+----+

# %%
# %fs ls dbfs:/Workspace/Users/anujkhare60@gmail.com/Data/employees.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/Users/anujkhare60@gmail.com/Data/employees.csv</td><td>employees.csv</td><td>83414</td><td>1771330235409</td></tr></tbody></table></div>

# %%
import pandas as pd

# Use this path format (no dbfs:, no /Workspace)
path = "/Workspace/Users/anujkhare60@gmail.com/Data/employees.csv"

df_pandas = pd.read_csv(path, header=0)

# Convert to Spark DF if you need Spark for larger operations
df = spark.createDataFrame(df_pandas)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employeeNumber</th><th>lastName</th><th>firstName</th><th>extension</th><th>email</th><th>officeCode</th><th>reportsTo</th><th>jobTitle</th></tr></thead><tbody><tr><td>1001</td><td>Jain</td><td>Anuj</td><td>x2224</td><td>anuj.jain@classicmodels.example</td><td>OF004</td><td>1250.0</td><td>Engineer</td></tr><tr><td>1002</td><td>More</td><td>Kirti</td><td>x5153</td><td>kirti.more@classicmodels.example</td><td>OF006</td><td>1692.0</td><td>Support Rep</td></tr><tr><td>1003</td><td>Singh</td><td>Tarun</td><td>x7820</td><td>tarun.singh@classicmodels.example</td><td>OF009</td><td>1189.0</td><td>Support Rep</td></tr><tr><td>1004</td><td>Patel</td><td>Vihaan</td><td>x2705</td><td>vihaan.patel@classicmodels.example</td><td>OF006</td><td>1487.0</td><td>Support Rep</td></tr><tr><td>1005</td><td>Khan</td><td>Zara</td><td>x8764</td><td>zara.khan@classicmodels.example</td><td>OF010</td><td>1610.0</td><td>